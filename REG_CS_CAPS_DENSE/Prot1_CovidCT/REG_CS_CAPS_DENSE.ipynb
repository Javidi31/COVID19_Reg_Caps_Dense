# %%
from __future__ import division, print_function, unicode_literals

# %%
# %tensorflow_version 1.x
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import pickle
import csv
import numpy as np
import tensorflow as tf
import pandas as pd
import httplib2
import os
import requests
from PIL import Image
import time
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
from google.colab import drive
drive.mount("/content/gdrive/")
# Out:
# Mounted at /content/gdrive/

# %%
tf.reset_default_graph()

# %%
np.random.seed(42)
tf.set_random_seed(42)

# %% [markdown]
# # Load Data

# %%
#!unzip '/mydrive/My Drive/Dataset/COVID19/Features/Features_COVIDCT_KFOLD_Lay72_Float32.zip' -d '/mydrive/My Drive/Dataset/COVID19/Features/Features_COVIDCT_KFOLD_Lay72_Float32'
# !unzip /content/gdrive/MyDrive/Covid19/CovidCT/Features_COVIDCT_KFOLD_Lay15_Float32.zip -d '/content/gdrive/My Drive/Covid19/CovidCT/Features_COVIDCT_KFOLD_Lay15_Float32'

# count of data on each folder
#!ls '/mydrive/My Drive/Dataset/COVID19/Features'
# !ls  "gdrive/My Drive/Covid19/Features_Prot2_Lay15/Features_Prot2_Lay15" | wc -l

# %%
checkpoint_path = 'gdrive/My Drive/Covid19/codes/REG_CS_CAPS_DENSE/Prot1_CovidCT/'

image_size = 28
img_channel = 128
all_img_no = 349+397
# tr_img_no = 17716
# ts_img_no = 1969

pathMain = '/content/gdrive/MyDrive/Covid19/CovidCT/Features_COVIDCT_KFOLD_Lay72_Float32/'

from tqdm.notebook import tqdm
if False:
  cnt = 0
  All = np.zeros( shape = (all_img_no,image_size,image_size,img_channel) )
  All_label = np.zeros( shape = (all_img_no))
  for i in tqdm(range(349)):
    path = pathMain + 'COVID/'
    path = path +  str(i)+ 'Out_lay72.pckl'  
    with open(path, 'rb') as f:
      All[cnt,:,:,:] = pickle.load(f)
    All_label[cnt] = 0
    cnt +=1
  
  for i in tqdm(range(397)):
    path = pathMain + 'NonCOVID/'
    path = path +  str(i+349)+ 'Out_lay72.pckl'  
    with open(path, 'rb') as f:
      All[cnt,:,:,:] = pickle.load(f)
    All_label[cnt] = 1
    cnt +=1

  with open(pathMain + 'DS.pckl', 'wb') as f:
    pickle.dump([All, All_label], f)

else:
  with open(pathMain + 'DS.pckl', 'rb') as f:
      All, All_label = pickle.load(f)

# %%
num_class = len(set(All_label))

# %%
X = tf.placeholder(shape=[None, image_size, image_size, img_channel], dtype=tf.float32, name="X")

# %% [markdown]
# # Primary Capsules

# %% [markdown]
# The first layer will be composed of 32 maps of 6×6 capsules each, where each capsule will output an 8D activation vector:

# %%
caps1_n_maps = 32
caps1_n_caps = caps1_n_maps * 6 * 6  # 1152 primary capsules 
# caps1_n_caps = caps1_n_maps * 11 * 11  # 41472 primary capsules    (FOR Cedar)
caps1_n_dims = 8

np.sqrt(11*11*256/(32*8))
# Out:
# 11.0

# %%
conv1_params = {
    "filters": 256,
    "kernel_size": 9,#------------------------------
    "strides": 1,
    "padding": "valid",
    "activation": tf.nn.relu,
}

conv2_params = {
    "filters": caps1_n_maps * caps1_n_dims, # 256 convolutional filters
    "kernel_size": 9,#------------------------------
    "strides": 2,
    "padding": "valid",
    "activation": tf.nn.relu
}

# %%
conv1 = tf.layers.conv2d(X, name="conv1", **conv1_params)
conv2 = tf.layers.conv2d(conv1, name="conv2", **conv2_params)
# Out:
# WARNING:tensorflow:From <ipython-input-15-3a2df923b7cc>:1: conv2d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv2D` instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/layers/convolutional.py:424: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.

# %%
caps1_raw = tf.reshape(conv2, [-1, caps1_n_caps, caps1_n_dims],
                       name="caps1_raw")

# %%
def squash(s, axis=-1, epsilon=1e-7, name=None):
    with tf.name_scope(name, default_name="squash"):
        squared_norm = tf.reduce_sum(tf.square(s), axis=axis,
                                     keep_dims=True)
        safe_norm = tf.sqrt(squared_norm + epsilon)
        squash_factor = squared_norm / (1. + squared_norm)
        unit_vector = s / safe_norm
        return squash_factor * unit_vector

# %%
caps1_output = squash(caps1_raw, name="caps1_output")
# Out:
# WARNING:tensorflow:From <ipython-input-17-8037c6cbfef1>:4: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %% [markdown]
# # Digit Capsules

# %% [markdown]
# ## Compute the Predicted Output Vectors

# %%
caps2_n_caps = num_class
caps2_n_dims = 16

# %%
init_sigma = 0.1

W_init = tf.random_normal(
    shape=(1, caps1_n_caps, caps2_n_caps, caps2_n_dims, caps1_n_dims),
    stddev=init_sigma, dtype=tf.float32, name="W_init")
W = tf.Variable(W_init, name="W")

# %%
batch_size = tf.shape(X)[0]
W_tiled = tf.tile(W, [batch_size, 1, 1, 1, 1], name="W_tiled")

# %%
caps1_output_expanded = tf.expand_dims(caps1_output, -1,
                                       name="caps1_output_expanded")
caps1_output_tile = tf.expand_dims(caps1_output_expanded, 2,
                                   name="caps1_output_tile")
caps1_output_tiled = tf.tile(caps1_output_tile, [1, 1, caps2_n_caps, 1, 1],
                             name="caps1_output_tiled")

# %%
caps2_predicted = tf.matmul(W_tiled, caps1_output_tiled,
                            name="caps2_predicted")

# %% [markdown]
# ## Routing by agreement

# %%
raw_weights = tf.zeros([batch_size, caps1_n_caps, caps2_n_caps, 1, 1],
                       dtype=np.float32, name="raw_weights")

# %% [markdown]
# ### Round 1

# %%
routing_weights = tf.nn.softmax(raw_weights, dim=2, name="routing_weights")
# Out:
# WARNING:tensorflow:From <ipython-input-25-86a489ae595f>:1: calling softmax (from tensorflow.python.ops.nn_ops) with dim is deprecated and will be removed in a future version.
# Instructions for updating:
# dim is deprecated, use axis instead

# %%
weighted_predictions = tf.multiply(routing_weights, caps2_predicted,
                                   name="weighted_predictions")
weighted_sum = tf.reduce_sum(weighted_predictions, axis=1, keep_dims=True,
                             name="weighted_sum")

# %%
caps2_output_round_1 = squash(weighted_sum, axis=-2,
                              name="caps2_output_round_1")

# %% [markdown]
# ### Round 2

# %%
caps2_output_round_1_tiled = tf.tile(
    caps2_output_round_1, [1, caps1_n_caps, 1, 1, 1],
    name="caps2_output_round_1_tiled")

# %%
agreement = tf.matmul(caps2_predicted, caps2_output_round_1_tiled,
                      transpose_a=True, name="agreement")

# %%
raw_weights_round_2 = tf.add(raw_weights, agreement,
                             name="raw_weights_round_2")

# %% [markdown]
# The rest of round 2 is the same as in round 1:

# %%
routing_weights_round_2 = tf.nn.softmax(raw_weights_round_2,
                                        dim=2,
                                        name="routing_weights_round_2")
weighted_predictions_round_2 = tf.multiply(routing_weights_round_2,
                                           caps2_predicted,
                                           name="weighted_predictions_round_2")
weighted_sum_round_2 = tf.reduce_sum(weighted_predictions_round_2,
                                     axis=1, keep_dims=True,
                                     name="weighted_sum_round_2")
caps2_output_round_2 = squash(weighted_sum_round_2,
                              axis=-2,
                              name="caps2_output_round_2")

# %%
caps2_output = caps2_output_round_2

# %% [markdown]
# # Estimated Class Probabilities (Length)

# %%
def safe_norm(s, axis=-1, epsilon=1e-7, keep_dims=False, name=None):
    with tf.name_scope(name, default_name="safe_norm"):
        squared_norm = tf.reduce_sum(tf.square(s), axis=axis,
                                     keep_dims=keep_dims)
        return tf.sqrt(squared_norm + epsilon)

# %%
y_proba = safe_norm(caps2_output, axis=-2, name="y_proba")

# %%
y_proba_argmax = tf.argmax(y_proba, axis=2, name="y_proba")

# %%
y_pred = tf.squeeze(y_proba_argmax, axis=[1,2], name="y_pred")

# %% [markdown]
# # Labels

# %%
y = tf.placeholder(shape=[None], dtype=tf.int64, name="y")

# %% [markdown]
# # Margin loss

# %%
m_plus = 0.9
m_minus = 0.1
lambda_ = 0.05

# %%
T = tf.one_hot(y, depth=caps2_n_caps, name="T")

# %%
caps2_output_norm = safe_norm(caps2_output, axis=-2, keep_dims=True,
                              name="caps2_output_norm")

# %%
present_error_raw = tf.square(tf.maximum(0., m_plus - caps2_output_norm),
                              name="present_error_raw")
present_error = tf.reshape(present_error_raw, shape=(-1, num_class),
                           name="present_error")

# %%
absent_error_raw = tf.square(tf.maximum(0., caps2_output_norm - m_minus),
                             name="absent_error_raw")
absent_error = tf.reshape(absent_error_raw, shape=(-1, num_class),
                          name="absent_error")

# %%
L = tf.add(T * present_error, lambda_ * (1.0 - T) * absent_error,
           name="L")

# %%
C = tf.placeholder(shape=[None,1], dtype=tf.float32)

L_CS = tf.multiply(L , C) 

margin_loss = tf.reduce_mean(tf.reduce_sum(L_CS, axis=1), name="margin_loss")

# %% [markdown]
# ## Final Loss

# %%
alpha = 0.00001


regularizer = tf.nn.l2_loss(W_tiled)
beta = 0.001
##loss = tf.add(loss_, beta * regularizer, name="loss")
loss = tf.add(margin_loss, beta * regularizer, name="loss")

loss_for_plot = tf.add(margin_loss, beta * regularizer / tf.cast(batch_size, tf.float32), name="loss") #**

# %% [markdown]
# ## Accuracy

# %%
correct = tf.equal(y, y_pred, name="correct")
accuracy = tf.reduce_mean(tf.cast(correct, tf.float32), name="accuracy")

# %% [markdown]
# ## Training Operations

# %%
optimizer = tf.train.AdamOptimizer(learning_rate=0.0003)
gvs = optimizer.compute_gradients(loss)
capped_gvs = [(tf.clip_by_value(grad, -1.0, 1.0), var) for grad, var in gvs]
training_op = optimizer.apply_gradients(capped_gvs)


#training_op = optimizer.minimize(loss, name="training_op")
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
init = tf.global_variables_initializer()
saver = tf.train.Saver( max_to_keep =1 , filename = 'TestName')

# %%
def getNextBatchTrain(batch_size):
  N = np.size(Train,0)
  idx = np.random.randint(0,N,batch_size)
  batchLabel = Train_label[idx]
  return Train[idx,:]  , batchLabel.astype('uint8')

# %% [markdown]
# # Training

# %%
from sklearn.model_selection import KFold
kfold = KFold(n_splits=10, shuffle=True,random_state=101)

checkpoint_path_main = checkpoint_path

fold_no = 0
start_fold = 1
for train, test in kfold.split(All, All_label):
  fold_no += 1
  if start_fold > fold_no:
    continue

  best_acc_val = 0
  checkpoint_path = checkpoint_path_main + 'Fold' + str(fold_no)

  Train = All[train]
  Train_label = All_label[train]
  Test = All[test]
  Test_label = All_label[test]

  n_epochs = 400
  batch_size = 8
  restore_checkpoint = False

  n_iterations_per_epoch = len(Train_label) // batch_size
  n_iterations_validation = len(Test_label) #// batch_size
  best_loss_val = np.infty

  with tf.Session() as sess:
      if restore_checkpoint and tf.train.checkpoint_exists(checkpoint_path):
          saver.restore(sess, checkpoint_path)
          with open(checkpoint_path + 'OtherVars', 'rb') as f:
              acc_trains, loss_trains, acc_tests, loss_tests ,time_per_epochs, start_epoch , y_pred_all = pickle.load(f)
              start_epoch += 1
          print('\nStarting from epoch: %.0f\n' %(start_epoch + 1))
      else:
          print('\nCheck point not loaded\n')
          init.run()
          loss_trains = []
          acc_trains = [] 
          loss_tests = []
          acc_tests = []
          time_per_epochs = []
          start_epoch = 0
          y_pred_all = np.zeros((n_iterations_validation,n_epochs))

      for epoch in range(start_epoch,n_epochs):
          startTime = time.time()
          loss_train = []
          acc_train=[]
          for iteration in range(1, n_iterations_per_epoch + 1):
              X_batch, y_batch = getNextBatchTrain(batch_size)
              CC = np.zeros((batch_size,1))
              for i in range(batch_size):
                CC[i] = 1 - np.sum(Train_label == y_batch[i]) / len(Train_label)
              # Run the training operation and measure the loss:
              _, loss_train_batch,acc_train_batch = sess.run(
                  [training_op, loss_for_plot,accuracy],
                  feed_dict = {X: X_batch.reshape([-1, image_size, image_size, img_channel]),
                            y: y_batch,
                            C: CC})
              print("\rIteration: {}/{} ({:.1f}%)  Loss: {:.5f}".format(
                        iteration, n_iterations_per_epoch,
                        iteration * 100 / n_iterations_per_epoch,
                        loss_train_batch),
                    end="")
              
              loss_train.append(loss_train_batch)
              acc_train.append(acc_train_batch)

          end_time = time.time()
          time_per_epochs.append(end_time - startTime)
          print('\nElapsed: %.1f' % (end_time - startTime))
          remainHour = (n_epochs-epoch) * (end_time - startTime)/3600
          print('Estimated remaining time: %.1f hours' % remainHour)

          acc_trains.append(np.mean(acc_train))
          loss_trains.append(np.mean(loss_train))

          #print("*****")
          #print("loss_train:",np.mean(loss_train)) #**        
          #print("acc_train",np.mean(acc_train)*100) #**Javidi
          #print("*****")

          # At the end of each epoch,
          # measure the validation loss and accuracy:
          loss_vals = []
          acc_vals = []
          
          for iteration in range(1, n_iterations_validation + 1):
              X_batch = Test[iteration-1:iteration]
              y_batch = Test_label[iteration-1:iteration].astype('uint8')
              CC = np.zeros((1,1))
              
              CC[0] = 1 - np.sum(Train_label == y_batch[0]) / len(Train_label)
              #X_batch, y_batch = getNextBatchTest(batch_size)
              loss_val, acc_val , y_pred_sample = sess.run(
                      [loss_for_plot, accuracy , y_pred],
                      feed_dict={X: X_batch.reshape([-1, image_size, image_size, img_channel]),
                                y: y_batch,
                                C: CC})

              loss_vals.append(loss_val)
              acc_vals.append(acc_val)
              y_pred_all[iteration-1 , epoch] =  y_pred_sample

              print("\rEvaluating the model: {}/{} ({:.1f}%)".format(
                        iteration, n_iterations_validation,
                        iteration * 100 / n_iterations_validation),
                    end=" " * 10)
              
          loss_val = np.mean(loss_vals)
          acc_val = np.mean(acc_vals)

          print("\rEpoch: {}  Train accuracy: {:.4f}%  Loss_train: {:.6f}  Val accuracy: {:.4f}%  Loss_test: {:.6f}{}".format(
              epoch + 1, np.mean(acc_train)*100,np.mean(loss_train),acc_val * 100, loss_val,
              " (improved)" if loss_val < best_loss_val else ""))


          loss_tests.append(loss_val) #**
          acc_tests.append(acc_val) #**

          #print(np.mean(loss_trains)) #**        
          

          #**
          np.savetxt(checkpoint_path+"loss_tr.csv", loss_trains, delimiter=",")
          np.savetxt(checkpoint_path+"loss_te.csv", loss_tests, delimiter=",")
          np.savetxt(checkpoint_path+"acc_tr.csv", acc_trains, delimiter=",")
          np.savetxt(checkpoint_path+"acc_te.csv", acc_tests, delimiter=",")

          # Save model all the time
            save_path = saver.save(sess, checkpoint_path)
            best_acc_val = acc_val
            label_best = y_pred_all[: , epoch]
            print(classification_report(Test_label, label_best,digits=4))

          with open(checkpoint_path + 'OtherVars', 'wb') as f:
              start_epoch = epoch
              pickle.dump([acc_trains, loss_trains, acc_tests, loss_tests ,time_per_epochs, start_epoch,y_pred_all], f)
# Out:
# Check point not loaded
#
# Iteration: 83/83 (100.0%)  Loss: 1.02140
# Elapsed: 9.2
# Estimated remaining time: 1.0 hours
# Epoch: 1  Train accuracy: 52.7108%  Loss_train: 1.242711  Val accuracy: 52.0000%  Loss_test: 1.014977 (improved)
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          0.0     0.0000    0.0000    0.0000        36
#          1.0     0.5200    1.0000    0.6842        39
#
#     accuracy                         0.5200        75
#    macro avg     0.2600    0.5000    0.3421        75
# weighted avg     0.2704    0.5200    0.3558        75
#
# Iteration: 83/83 (100.0%)  Loss: 0.69943
# Elapsed: 2.3
# Estimated remaining time: 0.3 hours
# Epoch: 2  Train accuracy: 53.3133%  Loss_train: 0.844958  Val accuracy: 58.6667%  Loss_test: 0.693433 (improved)
#               precision    recall  f1-score   support
#
#          0.0     0.8571    0.1667    0.2791        36
#          1.0     0.5588    0.9744    0.7103        39
#
#     accuracy                         0.5867        75
#    macro avg     0.7080    0.5705    0.4947        75
# weighted avg     0.7020    0.5867    0.5033        75
#
# Iteration: 83/83 (100.0%)  Loss: 0.48073
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 3  Train accuracy: 56.6265%  Loss_train: 0.580205  Val accuracy: 60.0000%  Loss_test: 0.478607 (improved)
#               precision    recall  f1-score   support
#
#          0.0     0.7500    0.2500    0.3750        36
#          1.0     0.5714    0.9231    0.7059        39
#
#     accuracy                         0.6000        75
#    macro avg     0.6607    0.5865    0.5404        75
# weighted avg     0.6571    0.6000    0.5471        75
#
# Iteration: 83/83 (100.0%)  Loss: 0.33357
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 4  Train accuracy: 64.3072%  Loss_train: 0.401094  Val accuracy: 56.0000%  Loss_test: 0.332460 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.22844
# Elapsed: 2.3
# Estimated remaining time: 0.3 hours
# Epoch: 5  Train accuracy: 75.4518%  Loss_train: 0.278618  Val accuracy: 70.6667%  Loss_test: 0.233614 (improved)
#               precision    recall  f1-score   support
#
#          0.0     0.6750    0.7500    0.7105        36
#          1.0     0.7429    0.6667    0.7027        39
#
#     accuracy                         0.7067        75
#    macro avg     0.7089    0.7083    0.7066        75
# weighted avg     0.7103    0.7067    0.7065        75
#
# Iteration: 83/83 (100.0%)  Loss: 0.16736
# Elapsed: 2.3
# Estimated remaining time: 0.3 hours
# Epoch: 6  Train accuracy: 73.1928%  Loss_train: 0.195698  Val accuracy: 62.6667%  Loss_test: 0.165687 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.11595
# Elapsed: 2.3
# Estimated remaining time: 0.3 hours
# Epoch: 7  Train accuracy: 73.4940%  Loss_train: 0.138110  Val accuracy: 68.0000%  Loss_test: 0.117210 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.08074
# Elapsed: 2.4
# Estimated remaining time: 0.3 hours
# Epoch: 8  Train accuracy: 79.8193%  Loss_train: 0.098246  Val accuracy: 69.3333%  Loss_test: 0.084699 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.06202
# Elapsed: 2.3
# Estimated remaining time: 0.3 hours
# Epoch: 9  Train accuracy: 67.1687%  Loss_train: 0.072812  Val accuracy: 60.0000%  Loss_test: 0.063138 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.04605
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 10  Train accuracy: 81.6265%  Loss_train: 0.052891  Val accuracy: 69.3333%  Loss_test: 0.047516 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.03652
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 11  Train accuracy: 78.4639%  Loss_train: 0.039138  Val accuracy: 62.6667%  Loss_test: 0.038575 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.03312
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 12  Train accuracy: 70.7831%  Loss_train: 0.032466  Val accuracy: 65.3333%  Loss_test: 0.029254 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.02729
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 13  Train accuracy: 79.5181%  Loss_train: 0.024260  Val accuracy: 66.6667%  Loss_test: 0.024056 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.01630
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 14  Train accuracy: 84.7892%  Loss_train: 0.019302  Val accuracy: 76.0000%  Loss_test: 0.024076 (improved)
#               precision    recall  f1-score   support
#
#          0.0     0.7250    0.8056    0.7632        36
#          1.0     0.8000    0.7179    0.7568        39
#
#     accuracy                         0.7600        75
#    macro avg     0.7625    0.7618    0.7600        75
# weighted avg     0.7640    0.7600    0.7598        75
#
# Iteration: 83/83 (100.0%)  Loss: 0.01323
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 15  Train accuracy: 83.5843%  Loss_train: 0.016358  Val accuracy: 74.6667%  Loss_test: 0.017905 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.01319
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 16  Train accuracy: 87.6506%  Loss_train: 0.013564  Val accuracy: 81.3333%  Loss_test: 0.018563 (improved)
#               precision    recall  f1-score   support
#
#          0.0     0.8438    0.7500    0.7941        36
#          1.0     0.7907    0.8718    0.8293        39
#
#     accuracy                         0.8133        75
#    macro avg     0.8172    0.8109    0.8117        75
# weighted avg     0.8162    0.8133    0.8124        75
#
# Iteration: 83/83 (100.0%)  Loss: 0.01447
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 17  Train accuracy: 86.2952%  Loss_train: 0.011895  Val accuracy: 74.6667%  Loss_test: 0.014129 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.01293
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 18  Train accuracy: 83.8855%  Loss_train: 0.012607  Val accuracy: 76.0000%  Loss_test: 0.013679 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.01048
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 19  Train accuracy: 87.8012%  Loss_train: 0.010211  Val accuracy: 80.0000%  Loss_test: 0.013188 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00414
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 20  Train accuracy: 92.0181%  Loss_train: 0.008210  Val accuracy: 81.3333%  Loss_test: 0.013267 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00648
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 21  Train accuracy: 89.9096%  Loss_train: 0.008348  Val accuracy: 78.6667%  Loss_test: 0.012725 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00687
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 22  Train accuracy: 89.3072%  Loss_train: 0.008593  Val accuracy: 77.3333%  Loss_test: 0.012102 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00622
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 23  Train accuracy: 90.6627%  Loss_train: 0.007034  Val accuracy: 82.6667%  Loss_test: 0.014877 (improved)
#               precision    recall  f1-score   support
#
#          0.0     0.7447    0.9722    0.8434        36
#          1.0     0.9643    0.6923    0.8060        39
#
#     accuracy                         0.8267        75
#    macro avg     0.8545    0.8323    0.8247        75
# weighted avg     0.8589    0.8267    0.8239        75
#
# Iteration: 83/83 (100.0%)  Loss: 0.00732
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 24  Train accuracy: 91.8675%  Loss_train: 0.005899  Val accuracy: 82.6667%  Loss_test: 0.013948 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00320
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 25  Train accuracy: 94.2771%  Loss_train: 0.005371  Val accuracy: 80.0000%  Loss_test: 0.013817 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00580
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 26  Train accuracy: 93.5241%  Loss_train: 0.005877  Val accuracy: 84.0000%  Loss_test: 0.014640 (improved)
#               precision    recall  f1-score   support
#
#          0.0     0.7609    0.9722    0.8537        36
#          1.0     0.9655    0.7179    0.8235        39
#
#     accuracy                         0.8400        75
#    macro avg     0.8632    0.8451    0.8386        75
# weighted avg     0.8673    0.8400    0.8380        75
#
# Iteration: 83/83 (100.0%)  Loss: 0.00208
# Elapsed: 2.5
# Estimated remaining time: 0.3 hours
# Epoch: 27  Train accuracy: 95.0301%  Loss_train: 0.004239  Val accuracy: 86.6667%  Loss_test: 0.015008 (improved)
#               precision    recall  f1-score   support
#
#          0.0     0.8421    0.8889    0.8649        36
#          1.0     0.8919    0.8462    0.8684        39
#
#     accuracy                         0.8667        75
#    macro avg     0.8670    0.8675    0.8666        75
# weighted avg     0.8680    0.8667    0.8667        75
#
# Iteration: 83/83 (100.0%)  Loss: 0.00451
# Elapsed: 2.4
# Estimated remaining time: 0.3 hours
# Epoch: 28  Train accuracy: 95.4819%  Loss_train: 0.004454  Val accuracy: 86.6667%  Loss_test: 0.012680 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00243
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 29  Train accuracy: 96.6867%  Loss_train: 0.003712  Val accuracy: 86.6667%  Loss_test: 0.016716 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00080
# Elapsed: 2.5
# Estimated remaining time: 0.3 hours
# Epoch: 30  Train accuracy: 96.8373%  Loss_train: 0.003744  Val accuracy: 86.6667%  Loss_test: 0.016567 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00823
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 31  Train accuracy: 98.0422%  Loss_train: 0.002956  Val accuracy: 86.6667%  Loss_test: 0.013961 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00031
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 32  Train accuracy: 97.8916%  Loss_train: 0.002631  Val accuracy: 86.6667%  Loss_test: 0.016340 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00397
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 33  Train accuracy: 99.2470%  Loss_train: 0.002307  Val accuracy: 86.6667%  Loss_test: 0.014347 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00706
# Elapsed: 2.4
# Estimated remaining time: 0.2 hours
# Epoch: 34  Train accuracy: 97.7410%  Loss_train: 0.003525  Val accuracy: 82.6667%  Loss_test: 0.011382 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00306
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 35  Train accuracy: 99.3976%  Loss_train: 0.001993  Val accuracy: 86.6667%  Loss_test: 0.015564 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00036
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 36  Train accuracy: 99.3976%  Loss_train: 0.001576  Val accuracy: 84.0000%  Loss_test: 0.018659 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00027
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 37  Train accuracy: 98.3434%  Loss_train: 0.002413  Val accuracy: 85.3333%  Loss_test: 0.018552 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00101
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 38  Train accuracy: 100.0000%  Loss_train: 0.001461  Val accuracy: 88.0000%  Loss_test: 0.018300 (improved)
#               precision    recall  f1-score   support
#
#          0.0     0.8462    0.9167    0.8800        36
#          1.0     0.9167    0.8462    0.8800        39
#
#     accuracy                         0.8800        75
#    macro avg     0.8814    0.8814    0.8800        75
# weighted avg     0.8828    0.8800    0.8800        75
#
# Iteration: 83/83 (100.0%)  Loss: 0.00217
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 39  Train accuracy: 99.5482%  Loss_train: 0.001513  Val accuracy: 85.3333%  Loss_test: 0.022400 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00046
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 40  Train accuracy: 99.5482%  Loss_train: 0.001494  Val accuracy: 90.6667%  Loss_test: 0.017473 (improved)
#               precision    recall  f1-score   support
#
#          0.0     0.8919    0.9167    0.9041        36
#          1.0     0.9211    0.8974    0.9091        39
#
#     accuracy                         0.9067        75
#    macro avg     0.9065    0.9071    0.9066        75
# weighted avg     0.9071    0.9067    0.9067        75
#
# Iteration: 83/83 (100.0%)  Loss: 0.00023
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 41  Train accuracy: 99.5482%  Loss_train: 0.001608  Val accuracy: 89.3333%  Loss_test: 0.019610 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00093
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 42  Train accuracy: 99.8494%  Loss_train: 0.000898  Val accuracy: 88.0000%  Loss_test: 0.019938 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00197
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 43  Train accuracy: 97.7410%  Loss_train: 0.002615  Val accuracy: 84.0000%  Loss_test: 0.024301 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00527
# Elapsed: 2.4
# Estimated remaining time: 0.2 hours
# Epoch: 44  Train accuracy: 98.0422%  Loss_train: 0.002849  Val accuracy: 86.6667%  Loss_test: 0.020651 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00049
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 45  Train accuracy: 99.6988%  Loss_train: 0.001387  Val accuracy: 89.3333%  Loss_test: 0.018066 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00079
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 46  Train accuracy: 100.0000%  Loss_train: 0.001038  Val accuracy: 89.3333%  Loss_test: 0.018762 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00454
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 47  Train accuracy: 98.7952%  Loss_train: 0.002024  Val accuracy: 85.3333%  Loss_test: 0.011585 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00499
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 48  Train accuracy: 98.7952%  Loss_train: 0.001773  Val accuracy: 80.0000%  Loss_test: 0.013243 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00048
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 49  Train accuracy: 98.1928%  Loss_train: 0.002341  Val accuracy: 86.6667%  Loss_test: 0.016346 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00322
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 50  Train accuracy: 99.8494%  Loss_train: 0.000883  Val accuracy: 88.0000%  Loss_test: 0.016100 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00081
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 51  Train accuracy: 99.5482%  Loss_train: 0.000832  Val accuracy: 89.3333%  Loss_test: 0.016798 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00021
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 52  Train accuracy: 100.0000%  Loss_train: 0.000902  Val accuracy: 89.3333%  Loss_test: 0.016987 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00046
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 53  Train accuracy: 99.8494%  Loss_train: 0.000710  Val accuracy: 90.6667%  Loss_test: 0.018225 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00044
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 54  Train accuracy: 100.0000%  Loss_train: 0.000543  Val accuracy: 88.0000%  Loss_test: 0.017511 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00034
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 55  Train accuracy: 100.0000%  Loss_train: 0.000508  Val accuracy: 89.3333%  Loss_test: 0.018167 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00021
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 56  Train accuracy: 100.0000%  Loss_train: 0.000370  Val accuracy: 88.0000%  Loss_test: 0.017876 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00086
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 57  Train accuracy: 100.0000%  Loss_train: 0.000485  Val accuracy: 89.3333%  Loss_test: 0.016824 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00020
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 58  Train accuracy: 100.0000%  Loss_train: 0.000439  Val accuracy: 88.0000%  Loss_test: 0.016600 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00023
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 59  Train accuracy: 100.0000%  Loss_train: 0.000538  Val accuracy: 86.6667%  Loss_test: 0.018866 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00028
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 60  Train accuracy: 99.8494%  Loss_train: 0.000352  Val accuracy: 89.3333%  Loss_test: 0.017321 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00029
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 61  Train accuracy: 100.0000%  Loss_train: 0.000362  Val accuracy: 89.3333%  Loss_test: 0.016395 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00044
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 62  Train accuracy: 100.0000%  Loss_train: 0.000347  Val accuracy: 89.3333%  Loss_test: 0.019149 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00015
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 63  Train accuracy: 100.0000%  Loss_train: 0.000449  Val accuracy: 89.3333%  Loss_test: 0.016889 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00022
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 64  Train accuracy: 100.0000%  Loss_train: 0.000374  Val accuracy: 88.0000%  Loss_test: 0.020277 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00016
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 65  Train accuracy: 100.0000%  Loss_train: 0.000330  Val accuracy: 89.3333%  Loss_test: 0.017165 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00017
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 66  Train accuracy: 100.0000%  Loss_train: 0.000228  Val accuracy: 86.6667%  Loss_test: 0.018668 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00039
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 67  Train accuracy: 100.0000%  Loss_train: 0.000254  Val accuracy: 82.6667%  Loss_test: 0.018845 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00028
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 68  Train accuracy: 100.0000%  Loss_train: 0.000227  Val accuracy: 89.3333%  Loss_test: 0.017147 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00014
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 69  Train accuracy: 100.0000%  Loss_train: 0.000204  Val accuracy: 86.6667%  Loss_test: 0.017747 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00015
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 70  Train accuracy: 100.0000%  Loss_train: 0.000206  Val accuracy: 89.3333%  Loss_test: 0.018217 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00020
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 71  Train accuracy: 100.0000%  Loss_train: 0.000255  Val accuracy: 90.6667%  Loss_test: 0.021698 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00237
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 72  Train accuracy: 100.0000%  Loss_train: 0.000363  Val accuracy: 88.0000%  Loss_test: 0.019447 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00021
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 73  Train accuracy: 100.0000%  Loss_train: 0.000314  Val accuracy: 86.6667%  Loss_test: 0.021876 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00594
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 74  Train accuracy: 95.7831%  Loss_train: 0.007227  Val accuracy: 60.0000%  Loss_test: 0.022608 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00190
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 75  Train accuracy: 91.8675%  Loss_train: 0.007802  Val accuracy: 90.6667%  Loss_test: 0.019677 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00406
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 76  Train accuracy: 93.2229%  Loss_train: 0.005418  Val accuracy: 88.0000%  Loss_test: 0.017648 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00113
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 77  Train accuracy: 99.5482%  Loss_train: 0.001171  Val accuracy: 85.3333%  Loss_test: 0.019936 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00044
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 78  Train accuracy: 99.3976%  Loss_train: 0.001634  Val accuracy: 89.3333%  Loss_test: 0.021189 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00026
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 79  Train accuracy: 100.0000%  Loss_train: 0.000562  Val accuracy: 89.3333%  Loss_test: 0.019686 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00045
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 80  Train accuracy: 100.0000%  Loss_train: 0.000319  Val accuracy: 90.6667%  Loss_test: 0.018898 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00021
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 81  Train accuracy: 100.0000%  Loss_train: 0.000338  Val accuracy: 90.6667%  Loss_test: 0.019351 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00059
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 82  Train accuracy: 100.0000%  Loss_train: 0.000263  Val accuracy: 90.6667%  Loss_test: 0.018428 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00038
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 83  Train accuracy: 100.0000%  Loss_train: 0.000281  Val accuracy: 88.0000%  Loss_test: 0.017990 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00038
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 84  Train accuracy: 100.0000%  Loss_train: 0.000220  Val accuracy: 85.3333%  Loss_test: 0.018357 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00068
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 85  Train accuracy: 100.0000%  Loss_train: 0.000214  Val accuracy: 86.6667%  Loss_test: 0.018115 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00025
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 86  Train accuracy: 100.0000%  Loss_train: 0.000222  Val accuracy: 89.3333%  Loss_test: 0.017124 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00027
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 87  Train accuracy: 100.0000%  Loss_train: 0.000213  Val accuracy: 89.3333%  Loss_test: 0.018824 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00013
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 88  Train accuracy: 100.0000%  Loss_train: 0.000189  Val accuracy: 89.3333%  Loss_test: 0.018476 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00014
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 89  Train accuracy: 100.0000%  Loss_train: 0.000181  Val accuracy: 89.3333%  Loss_test: 0.017034 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00011
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 90  Train accuracy: 100.0000%  Loss_train: 0.000184  Val accuracy: 89.3333%  Loss_test: 0.017658 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00013
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 91  Train accuracy: 100.0000%  Loss_train: 0.000162  Val accuracy: 88.0000%  Loss_test: 0.017058 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00014
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 92  Train accuracy: 100.0000%  Loss_train: 0.000160  Val accuracy: 88.0000%  Loss_test: 0.017916 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00009
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 93  Train accuracy: 100.0000%  Loss_train: 0.000161  Val accuracy: 88.0000%  Loss_test: 0.017744 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.01466
# Elapsed: 2.4
# Estimated remaining time: 0.2 hours
# Epoch: 94  Train accuracy: 84.9398%  Loss_train: 0.008412  Val accuracy: 48.0000%  Loss_test: 0.017158 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.01880
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 95  Train accuracy: 73.3434%  Loss_train: 0.011112  Val accuracy: 80.0000%  Loss_test: 0.015709 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00057
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 96  Train accuracy: 96.2349%  Loss_train: 0.005210  Val accuracy: 85.3333%  Loss_test: 0.022429 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00037
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 97  Train accuracy: 99.8494%  Loss_train: 0.001042  Val accuracy: 85.3333%  Loss_test: 0.025936 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00038
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 98  Train accuracy: 99.6988%  Loss_train: 0.000761  Val accuracy: 89.3333%  Loss_test: 0.019252 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00019
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 99  Train accuracy: 100.0000%  Loss_train: 0.000364  Val accuracy: 89.3333%  Loss_test: 0.019056 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00018
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 100  Train accuracy: 100.0000%  Loss_train: 0.000359  Val accuracy: 89.3333%  Loss_test: 0.019902 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00014
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 101  Train accuracy: 100.0000%  Loss_train: 0.000242  Val accuracy: 90.6667%  Loss_test: 0.017939 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00063
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 102  Train accuracy: 100.0000%  Loss_train: 0.000254  Val accuracy: 85.3333%  Loss_test: 0.019385 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00017
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 103  Train accuracy: 100.0000%  Loss_train: 0.000193  Val accuracy: 85.3333%  Loss_test: 0.017988 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00012
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 104  Train accuracy: 100.0000%  Loss_train: 0.000180  Val accuracy: 86.6667%  Loss_test: 0.017289 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00011
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 105  Train accuracy: 100.0000%  Loss_train: 0.000191  Val accuracy: 85.3333%  Loss_test: 0.018075 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00010
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 106  Train accuracy: 100.0000%  Loss_train: 0.000160  Val accuracy: 85.3333%  Loss_test: 0.016741 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00011
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 107  Train accuracy: 100.0000%  Loss_train: 0.000151  Val accuracy: 89.3333%  Loss_test: 0.017015 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00013
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 108  Train accuracy: 100.0000%  Loss_train: 0.000161  Val accuracy: 84.0000%  Loss_test: 0.017770 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00012
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 109  Train accuracy: 100.0000%  Loss_train: 0.000150  Val accuracy: 84.0000%  Loss_test: 0.017968 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00009
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 110  Train accuracy: 100.0000%  Loss_train: 0.000143  Val accuracy: 86.6667%  Loss_test: 0.017865 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00010
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 111  Train accuracy: 100.0000%  Loss_train: 0.000149  Val accuracy: 84.0000%  Loss_test: 0.017357 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00010
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 112  Train accuracy: 100.0000%  Loss_train: 0.000134  Val accuracy: 84.0000%  Loss_test: 0.016853 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00009
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 113  Train accuracy: 100.0000%  Loss_train: 0.000129  Val accuracy: 82.6667%  Loss_test: 0.016623 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00017
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 114  Train accuracy: 100.0000%  Loss_train: 0.000141  Val accuracy: 82.6667%  Loss_test: 0.017376 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00016
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 115  Train accuracy: 100.0000%  Loss_train: 0.000128  Val accuracy: 89.3333%  Loss_test: 0.016793 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00010
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 116  Train accuracy: 100.0000%  Loss_train: 0.000128  Val accuracy: 88.0000%  Loss_test: 0.017503 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00011
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 117  Train accuracy: 100.0000%  Loss_train: 0.000113  Val accuracy: 84.0000%  Loss_test: 0.017259 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00010
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 118  Train accuracy: 100.0000%  Loss_train: 0.000118  Val accuracy: 86.6667%  Loss_test: 0.017642 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00008
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 119  Train accuracy: 100.0000%  Loss_train: 0.000131  Val accuracy: 89.3333%  Loss_test: 0.017350 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00027
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 120  Train accuracy: 100.0000%  Loss_train: 0.000118  Val accuracy: 89.3333%  Loss_test: 0.016894 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00008
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 121  Train accuracy: 100.0000%  Loss_train: 0.000132  Val accuracy: 88.0000%  Loss_test: 0.015182 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00012
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 122  Train accuracy: 100.0000%  Loss_train: 0.000111  Val accuracy: 86.6667%  Loss_test: 0.016939 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00014
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 123  Train accuracy: 100.0000%  Loss_train: 0.000106  Val accuracy: 86.6667%  Loss_test: 0.016569 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00009
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 124  Train accuracy: 100.0000%  Loss_train: 0.000116  Val accuracy: 88.0000%  Loss_test: 0.015660 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00027
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 125  Train accuracy: 100.0000%  Loss_train: 0.000116  Val accuracy: 90.6667%  Loss_test: 0.016241 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00008
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 126  Train accuracy: 100.0000%  Loss_train: 0.000221  Val accuracy: 86.6667%  Loss_test: 0.018871 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00009
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 127  Train accuracy: 100.0000%  Loss_train: 0.000153  Val accuracy: 88.0000%  Loss_test: 0.016689 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00009
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 128  Train accuracy: 99.8494%  Loss_train: 0.000285  Val accuracy: 80.0000%  Loss_test: 0.039704 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.01121
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 129  Train accuracy: 80.1205%  Loss_train: 0.010671  Val accuracy: 54.6667%  Loss_test: 0.015927 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.01020
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 130  Train accuracy: 71.3855%  Loss_train: 0.010772  Val accuracy: 52.0000%  Loss_test: 0.017046 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00030
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 131  Train accuracy: 88.4036%  Loss_train: 0.005733  Val accuracy: 86.6667%  Loss_test: 0.016536 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00018
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 132  Train accuracy: 99.5482%  Loss_train: 0.001101  Val accuracy: 86.6667%  Loss_test: 0.017441 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00046
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 133  Train accuracy: 100.0000%  Loss_train: 0.000445  Val accuracy: 86.6667%  Loss_test: 0.021230 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00017
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 134  Train accuracy: 100.0000%  Loss_train: 0.000243  Val accuracy: 86.6667%  Loss_test: 0.019345 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00011
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 135  Train accuracy: 100.0000%  Loss_train: 0.000216  Val accuracy: 88.0000%  Loss_test: 0.017762 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00011
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 136  Train accuracy: 100.0000%  Loss_train: 0.000167  Val accuracy: 89.3333%  Loss_test: 0.016353 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00009
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 137  Train accuracy: 100.0000%  Loss_train: 0.000181  Val accuracy: 86.6667%  Loss_test: 0.018841 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00012
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 138  Train accuracy: 100.0000%  Loss_train: 0.000159  Val accuracy: 90.6667%  Loss_test: 0.017342 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00009
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 139  Train accuracy: 100.0000%  Loss_train: 0.000147  Val accuracy: 86.6667%  Loss_test: 0.017140 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00012
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 140  Train accuracy: 100.0000%  Loss_train: 0.000144  Val accuracy: 88.0000%  Loss_test: 0.017960 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00015
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 141  Train accuracy: 100.0000%  Loss_train: 0.000125  Val accuracy: 88.0000%  Loss_test: 0.016759 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00059
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 142  Train accuracy: 100.0000%  Loss_train: 0.000141  Val accuracy: 88.0000%  Loss_test: 0.017409 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00015
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 143  Train accuracy: 100.0000%  Loss_train: 0.000133  Val accuracy: 85.3333%  Loss_test: 0.017213 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00011
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 144  Train accuracy: 100.0000%  Loss_train: 0.000118  Val accuracy: 86.6667%  Loss_test: 0.017731 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00008
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 145  Train accuracy: 100.0000%  Loss_train: 0.000115  Val accuracy: 86.6667%  Loss_test: 0.017170 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00011
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 146  Train accuracy: 100.0000%  Loss_train: 0.000110  Val accuracy: 86.6667%  Loss_test: 0.016792 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00040
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 147  Train accuracy: 100.0000%  Loss_train: 0.000118  Val accuracy: 88.0000%  Loss_test: 0.016501 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00009
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 148  Train accuracy: 100.0000%  Loss_train: 0.000107  Val accuracy: 86.6667%  Loss_test: 0.017491 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00010
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 149  Train accuracy: 100.0000%  Loss_train: 0.000113  Val accuracy: 89.3333%  Loss_test: 0.017130 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00009
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 150  Train accuracy: 100.0000%  Loss_train: 0.000119  Val accuracy: 86.6667%  Loss_test: 0.016538 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00035
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 151  Train accuracy: 100.0000%  Loss_train: 0.000118  Val accuracy: 86.6667%  Loss_test: 0.017810 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00010
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 152  Train accuracy: 100.0000%  Loss_train: 0.000100  Val accuracy: 85.3333%  Loss_test: 0.016855 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00011
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 153  Train accuracy: 100.0000%  Loss_train: 0.000106  Val accuracy: 86.6667%  Loss_test: 0.016895 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00008
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 154  Train accuracy: 100.0000%  Loss_train: 0.000098  Val accuracy: 88.0000%  Loss_test: 0.016727 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00009
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 155  Train accuracy: 100.0000%  Loss_train: 0.000092  Val accuracy: 88.0000%  Loss_test: 0.016118 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00007
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 156  Train accuracy: 100.0000%  Loss_train: 0.000096  Val accuracy: 88.0000%  Loss_test: 0.015852 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00008
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 157  Train accuracy: 100.0000%  Loss_train: 0.000105  Val accuracy: 88.0000%  Loss_test: 0.016208 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00008
# Elapsed: 2.4
# Estimated remaining time: 0.2 hours
# Epoch: 158  Train accuracy: 100.0000%  Loss_train: 0.000092  Val accuracy: 86.6667%  Loss_test: 0.015937 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00007
# Elapsed: 2.4
# Estimated remaining time: 0.2 hours
# Epoch: 159  Train accuracy: 100.0000%  Loss_train: 0.000098  Val accuracy: 86.6667%  Loss_test: 0.015997 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00009
# Elapsed: 2.4
# Estimated remaining time: 0.2 hours
# Epoch: 160  Train accuracy: 100.0000%  Loss_train: 0.000094  Val accuracy: 88.0000%  Loss_test: 0.015479 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00011
# Elapsed: 2.4
# Estimated remaining time: 0.2 hours
# Epoch: 161  Train accuracy: 100.0000%  Loss_train: 0.000091  Val accuracy: 88.0000%  Loss_test: 0.015420 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00021
# Elapsed: 2.4
# Estimated remaining time: 0.2 hours
# Epoch: 162  Train accuracy: 100.0000%  Loss_train: 0.000122  Val accuracy: 85.3333%  Loss_test: 0.019555 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.01669
# Elapsed: 2.4
# Estimated remaining time: 0.2 hours
# Epoch: 163  Train accuracy: 91.8675%  Loss_train: 0.005586  Val accuracy: 66.6667%  Loss_test: 0.016923 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00178
# Elapsed: 2.4
# Estimated remaining time: 0.2 hours
# Epoch: 164  Train accuracy: 71.3855%  Loss_train: 0.010622  Val accuracy: 84.0000%  Loss_test: 0.016089 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00031
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 165  Train accuracy: 99.5482%  Loss_train: 0.001097  Val accuracy: 88.0000%  Loss_test: 0.019549 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00016
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 166  Train accuracy: 99.6988%  Loss_train: 0.000719  Val accuracy: 88.0000%  Loss_test: 0.020891 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00012
# Elapsed: 2.4
# Estimated remaining time: 0.2 hours
# Epoch: 167  Train accuracy: 100.0000%  Loss_train: 0.000332  Val accuracy: 84.0000%  Loss_test: 0.025761 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00020
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 168  Train accuracy: 99.8494%  Loss_train: 0.000829  Val accuracy: 85.3333%  Loss_test: 0.022073 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00022
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 169  Train accuracy: 99.6988%  Loss_train: 0.000569  Val accuracy: 88.0000%  Loss_test: 0.022803 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00023
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 170  Train accuracy: 100.0000%  Loss_train: 0.000246  Val accuracy: 88.0000%  Loss_test: 0.020409 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00009
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 171  Train accuracy: 100.0000%  Loss_train: 0.000164  Val accuracy: 88.0000%  Loss_test: 0.018282 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00032
# Elapsed: 2.3
# Estimated remaining time: 0.1 hours
# Epoch: 172  Train accuracy: 100.0000%  Loss_train: 0.000120  Val accuracy: 88.0000%  Loss_test: 0.017868 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00010
# Elapsed: 2.3
# Estimated remaining time: 0.1 hours
# Epoch: 173  Train accuracy: 100.0000%  Loss_train: 0.000114  Val accuracy: 88.0000%  Loss_test: 0.017393 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00010
# Elapsed: 2.3
# Estimated remaining time: 0.1 hours
# Epoch: 174  Train accuracy: 100.0000%  Loss_train: 0.000107  Val accuracy: 88.0000%  Loss_test: 0.016954 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00010
# Elapsed: 2.2
# Estimated remaining time: 0.1 hours
# Epoch: 175  Train accuracy: 100.0000%  Loss_train: 0.000106  Val accuracy: 88.0000%  Loss_test: 0.017603 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00006
# Elapsed: 2.2
# Estimated remaining time: 0.1 hours
# Epoch: 176  Train accuracy: 100.0000%  Loss_train: 0.000098  Val accuracy: 88.0000%  Loss_test: 0.017410 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00006
# Elapsed: 2.3
# Estimated remaining time: 0.1 hours
# Epoch: 177  Train accuracy: 100.0000%  Loss_train: 0.000094  Val accuracy: 88.0000%  Loss_test: 0.016879 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00009
# Elapsed: 2.3
# Estimated remaining time: 0.1 hours
# Epoch: 178  Train accuracy: 100.0000%  Loss_train: 0.000100  Val accuracy: 88.0000%  Loss_test: 0.016505 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00007
# Elapsed: 2.2
# Estimated remaining time: 0.1 hours
# Epoch: 179  Train accuracy: 100.0000%  Loss_train: 0.000087  Val accuracy: 88.0000%  Loss_test: 0.016930 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00012
# Elapsed: 2.3
# Estimated remaining time: 0.1 hours
# Epoch: 180  Train accuracy: 100.0000%  Loss_train: 0.000092  Val accuracy: 88.0000%  Loss_test: 0.017818 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00006
# Elapsed: 2.3
# Estimated remaining time: 0.1 hours
# Epoch: 181  Train accuracy: 100.0000%  Loss_train: 0.000087  Val accuracy: 88.0000%  Loss_test: 0.017354 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00009
# Elapsed: 2.3
# Estimated remaining time: 0.1 hours
# Epoch: 182  Train accuracy: 100.0000%  Loss_train: 0.000088  Val accuracy: 85.3333%  Loss_test: 0.018573 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00007
# Elapsed: 2.3
# Estimated remaining time: 0.1 hours
# Epoch: 183  Train accuracy: 100.0000%  Loss_train: 0.000092  Val accuracy: 86.6667%  Loss_test: 0.020120 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00006
# Elapsed: 2.3
# Estimated remaining time: 0.1 hours
# Epoch: 184  Train accuracy: 100.0000%  Loss_train: 0.000086  Val accuracy: 88.0000%  Loss_test: 0.018171 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00007
# Elapsed: 2.3
# Estimated remaining time: 0.1 hours
# Epoch: 185  Train accuracy: 100.0000%  Loss_train: 0.000085  Val accuracy: 88.0000%  Loss_test: 0.019152 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00008
# Elapsed: 2.3
# Estimated remaining time: 0.1 hours
# Epoch: 186  Train accuracy: 100.0000%  Loss_train: 0.000084  Val accuracy: 88.0000%  Loss_test: 0.017464 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00006
# Elapsed: 2.3
# Estimated remaining time: 0.1 hours
# Epoch: 187  Train accuracy: 100.0000%  Loss_train: 0.000080  Val accuracy: 86.6667%  Loss_test: 0.019003 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00009
# Elapsed: 2.3
# Estimated remaining time: 0.1 hours
# Epoch: 188  Train accuracy: 100.0000%  Loss_train: 0.000087  Val accuracy: 88.0000%  Loss_test: 0.017363 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00009
# Elapsed: 2.3
# Estimated remaining time: 0.1 hours
# Epoch: 189  Train accuracy: 100.0000%  Loss_train: 0.000084  Val accuracy: 88.0000%  Loss_test: 0.016838 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00007
# Elapsed: 2.2
# Estimated remaining time: 0.1 hours
# Epoch: 190  Train accuracy: 100.0000%  Loss_train: 0.000079  Val accuracy: 88.0000%  Loss_test: 0.017786 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00013
# Elapsed: 2.3
# Estimated remaining time: 0.1 hours
# Epoch: 191  Train accuracy: 100.0000%  Loss_train: 0.000080  Val accuracy: 88.0000%  Loss_test: 0.018159 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00006
# Elapsed: 2.2
# Estimated remaining time: 0.1 hours
# Epoch: 192  Train accuracy: 100.0000%  Loss_train: 0.000083  Val accuracy: 88.0000%  Loss_test: 0.016676 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00006
# Elapsed: 2.2
# Estimated remaining time: 0.1 hours
# Epoch: 193  Train accuracy: 100.0000%  Loss_train: 0.000079  Val accuracy: 88.0000%  Loss_test: 0.017158 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00006
# Elapsed: 2.2
# Estimated remaining time: 0.1 hours
# Epoch: 194  Train accuracy: 100.0000%  Loss_train: 0.000076  Val accuracy: 88.0000%  Loss_test: 0.016550 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00009
# Elapsed: 2.2
# Estimated remaining time: 0.1 hours
# Epoch: 195  Train accuracy: 100.0000%  Loss_train: 0.000073  Val accuracy: 88.0000%  Loss_test: 0.016575 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00010
# Elapsed: 2.3
# Estimated remaining time: 0.1 hours
# Epoch: 196  Train accuracy: 100.0000%  Loss_train: 0.000076  Val accuracy: 88.0000%  Loss_test: 0.015942 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00008
# Elapsed: 2.2
# Estimated remaining time: 0.1 hours
# Epoch: 197  Train accuracy: 100.0000%  Loss_train: 0.000073  Val accuracy: 88.0000%  Loss_test: 0.016210 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00008
# Elapsed: 2.2
# Estimated remaining time: 0.1 hours
# Epoch: 198  Train accuracy: 100.0000%  Loss_train: 0.000076  Val accuracy: 88.0000%  Loss_test: 0.017829 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00049
# Elapsed: 2.2
# Estimated remaining time: 0.1 hours
# Epoch: 199  Train accuracy: 100.0000%  Loss_train: 0.000200  Val accuracy: 77.3333%  Loss_test: 0.036253 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.01291
# Elapsed: 2.2
# Estimated remaining time: 0.1 hours
# Epoch: 200  Train accuracy: 54.0663%  Loss_train: 0.016580  Val accuracy: 48.0000%  Loss_test: 0.019379 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.01406
# Elapsed: 2.2
# Estimated remaining time: 0.1 hours
# Epoch: 201  Train accuracy: 59.3373%  Loss_train: 0.014836  Val accuracy: 48.0000%  Loss_test: 0.022025 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00267
# Elapsed: 2.2
# Estimated remaining time: 0.1 hours
# Epoch: 202  Train accuracy: 79.8193%  Loss_train: 0.007493  Val accuracy: 84.0000%  Loss_test: 0.024465 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00031
# Elapsed: 2.2
# Estimated remaining time: 0.1 hours
# Epoch: 203  Train accuracy: 99.0964%  Loss_train: 0.001586  Val accuracy: 85.3333%  Loss_test: 0.019398 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00011
# Elapsed: 2.3
# Estimated remaining time: 0.1 hours
# Epoch: 204  Train accuracy: 100.0000%  Loss_train: 0.000277  Val accuracy: 86.6667%  Loss_test: 0.019828 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00037
# Elapsed: 2.4
# Estimated remaining time: 0.1 hours
# Epoch: 205  Train accuracy: 100.0000%  Loss_train: 0.000207  Val accuracy: 88.0000%  Loss_test: 0.021267 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00008
# Elapsed: 2.3
# Estimated remaining time: 0.1 hours
# Epoch: 206  Train accuracy: 100.0000%  Loss_train: 0.000150  Val accuracy: 86.6667%  Loss_test: 0.020614 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00008
# Elapsed: 2.3
# Estimated remaining time: 0.1 hours
# Epoch: 207  Train accuracy: 100.0000%  Loss_train: 0.000139  Val accuracy: 90.6667%  Loss_test: 0.017857 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00013
# Elapsed: 2.4
# Estimated remaining time: 0.1 hours
# Epoch: 208  Train accuracy: 100.0000%  Loss_train: 0.000117  Val accuracy: 86.6667%  Loss_test: 0.018587 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00009
# Elapsed: 2.3
# Estimated remaining time: 0.1 hours
# Epoch: 209  Train accuracy: 100.0000%  Loss_train: 0.000110  Val accuracy: 88.0000%  Loss_test: 0.018280 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00008
# Elapsed: 2.3
# Estimated remaining time: 0.1 hours
# Epoch: 210  Train accuracy: 100.0000%  Loss_train: 0.000103  Val accuracy: 88.0000%  Loss_test: 0.018788 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00007
# Elapsed: 2.3
# Estimated remaining time: 0.1 hours
# Epoch: 211  Train accuracy: 100.0000%  Loss_train: 0.000096  Val accuracy: 88.0000%  Loss_test: 0.018652 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00010
# Elapsed: 2.3
# Estimated remaining time: 0.1 hours
# Epoch: 212  Train accuracy: 100.0000%  Loss_train: 0.000090  Val accuracy: 88.0000%  Loss_test: 0.018170 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00014
# Elapsed: 2.2
# Estimated remaining time: 0.1 hours
# Epoch: 213  Train accuracy: 100.0000%  Loss_train: 0.000093  Val accuracy: 88.0000%  Loss_test: 0.017709 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00009
# Elapsed: 2.2
# Estimated remaining time: 0.1 hours
# Epoch: 214  Train accuracy: 100.0000%  Loss_train: 0.000091  Val accuracy: 85.3333%  Loss_test: 0.020035 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00007
# Elapsed: 2.2
# Estimated remaining time: 0.1 hours
# ...
#               precision    recall  f1-score   support
#
#          0.0     0.7333    0.6111    0.6667        36
#          1.0     0.6889    0.7949    0.7381        39
#
#     accuracy                         0.7067        75
#    macro avg     0.7111    0.7030    0.7024        75
# weighted avg     0.7102    0.7067    0.7038        75
#
# Iteration: 83/83 (100.0%)  Loss: 0.08476
# Elapsed: 2.3
# Estimated remaining time: 0.3 hours
# Epoch: 8  Train accuracy: 70.1807%  Loss_train: 0.099435  Val accuracy: 70.6667%  Loss_test: 0.084855 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.05935
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 9  Train accuracy: 74.5482%  Loss_train: 0.072235  Val accuracy: 64.0000%  Loss_test: 0.062415 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.04344
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 10  Train accuracy: 62.5000%  Loss_train: 0.054102  Val accuracy: 76.0000%  Loss_test: 0.047518 (improved)
#               precision    recall  f1-score   support
#
#          0.0     0.7500    0.7500    0.7500        36
#          1.0     0.7692    0.7692    0.7692        39
#
#     accuracy                         0.7600        75
#    macro avg     0.7596    0.7596    0.7596        75
# weighted avg     0.7600    0.7600    0.7600        75
#
# Iteration: 83/83 (100.0%)  Loss: 0.03231
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 11  Train accuracy: 78.9157%  Loss_train: 0.038661  Val accuracy: 72.0000%  Loss_test: 0.036695 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.02947
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 12  Train accuracy: 80.8735%  Loss_train: 0.028564  Val accuracy: 49.3333%  Loss_test: 0.030696 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.02252
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 13  Train accuracy: 67.0181%  Loss_train: 0.026315  Val accuracy: 70.6667%  Loss_test: 0.025109 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.01275
# Elapsed: 2.4
# Estimated remaining time: 0.3 hours
# Epoch: 14  Train accuracy: 80.8735%  Loss_train: 0.020107  Val accuracy: 74.6667%  Loss_test: 0.021444 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.01144
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 15  Train accuracy: 86.8976%  Loss_train: 0.014668  Val accuracy: 80.0000%  Loss_test: 0.016585 (improved)
#               precision    recall  f1-score   support
#
#          0.0     0.8000    0.7778    0.7887        36
#          1.0     0.8000    0.8205    0.8101        39
#
#     accuracy                         0.8000        75
#    macro avg     0.8000    0.7991    0.7994        75
# weighted avg     0.8000    0.8000    0.7999        75
#
# Iteration: 83/83 (100.0%)  Loss: 0.00896
# Elapsed: 2.4
# Estimated remaining time: 0.3 hours
# Epoch: 16  Train accuracy: 88.1024%  Loss_train: 0.012469  Val accuracy: 76.0000%  Loss_test: 0.015379 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.01201
# Elapsed: 2.4
# Estimated remaining time: 0.3 hours
# Epoch: 17  Train accuracy: 90.2108%  Loss_train: 0.010227  Val accuracy: 69.3333%  Loss_test: 0.023802 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.01083
# Elapsed: 2.4
# Estimated remaining time: 0.3 hours
# Epoch: 18  Train accuracy: 88.5542%  Loss_train: 0.008925  Val accuracy: 73.3333%  Loss_test: 0.016918 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00823
# Elapsed: 2.5
# Estimated remaining time: 0.3 hours
# Epoch: 19  Train accuracy: 90.2108%  Loss_train: 0.008645  Val accuracy: 78.6667%  Loss_test: 0.012099 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00408
# Elapsed: 2.4
# Estimated remaining time: 0.2 hours
# Epoch: 20  Train accuracy: 92.6205%  Loss_train: 0.007423  Val accuracy: 80.0000%  Loss_test: 0.011857 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00560
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 21  Train accuracy: 94.8795%  Loss_train: 0.005461  Val accuracy: 80.0000%  Loss_test: 0.016651 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00440
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 22  Train accuracy: 92.9217%  Loss_train: 0.006401  Val accuracy: 80.0000%  Loss_test: 0.014125 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00223
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 23  Train accuracy: 92.1687%  Loss_train: 0.005562  Val accuracy: 84.0000%  Loss_test: 0.012804 (improved)
#               precision    recall  f1-score   support
#
#          0.0     0.8158    0.8611    0.8378        36
#          1.0     0.8649    0.8205    0.8421        39
#
#     accuracy                         0.8400        75
#    macro avg     0.8403    0.8408    0.8400        75
# weighted avg     0.8413    0.8400    0.8401        75
#
# Iteration: 83/83 (100.0%)  Loss: 0.00260
# Elapsed: 2.4
# Estimated remaining time: 0.2 hours
# Epoch: 24  Train accuracy: 95.3313%  Loss_train: 0.004676  Val accuracy: 80.0000%  Loss_test: 0.015801 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00262
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 25  Train accuracy: 93.3735%  Loss_train: 0.006458  Val accuracy: 76.0000%  Loss_test: 0.020102 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00092
# Elapsed: 2.4
# Estimated remaining time: 0.2 hours
# Epoch: 26  Train accuracy: 94.4277%  Loss_train: 0.004197  Val accuracy: 81.3333%  Loss_test: 0.015858 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00459
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 27  Train accuracy: 94.8795%  Loss_train: 0.004352  Val accuracy: 84.0000%  Loss_test: 0.011864 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00166
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 28  Train accuracy: 91.7169%  Loss_train: 0.006853  Val accuracy: 82.6667%  Loss_test: 0.015408 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00456
# Elapsed: 2.4
# Estimated remaining time: 0.2 hours
# Epoch: 29  Train accuracy: 95.1807%  Loss_train: 0.004291  Val accuracy: 88.0000%  Loss_test: 0.010646 (improved)
#               precision    recall  f1-score   support
#
#          0.0     0.8293    0.9444    0.8831        36
#          1.0     0.9412    0.8205    0.8767        39
#
#     accuracy                         0.8800        75
#    macro avg     0.8852    0.8825    0.8799        75
# weighted avg     0.8875    0.8800    0.8798        75
#
# Iteration: 83/83 (100.0%)  Loss: 0.00987
# Elapsed: 2.4
# Estimated remaining time: 0.2 hours
# Epoch: 30  Train accuracy: 97.5904%  Loss_train: 0.003189  Val accuracy: 85.3333%  Loss_test: 0.010576 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00640
# Elapsed: 2.4
# Estimated remaining time: 0.2 hours
# Epoch: 31  Train accuracy: 98.1928%  Loss_train: 0.003169  Val accuracy: 82.6667%  Loss_test: 0.011840 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00216
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 32  Train accuracy: 98.6446%  Loss_train: 0.002393  Val accuracy: 86.6667%  Loss_test: 0.009621 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00060
# Elapsed: 2.5
# Estimated remaining time: 0.3 hours
# Epoch: 33  Train accuracy: 97.7410%  Loss_train: 0.002441  Val accuracy: 84.0000%  Loss_test: 0.008942 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00053
# Elapsed: 2.4
# Estimated remaining time: 0.2 hours
# Epoch: 34  Train accuracy: 98.1928%  Loss_train: 0.002241  Val accuracy: 88.0000%  Loss_test: 0.013632 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00126
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 35  Train accuracy: 97.5904%  Loss_train: 0.002556  Val accuracy: 82.6667%  Loss_test: 0.012089 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00022
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 36  Train accuracy: 98.4940%  Loss_train: 0.001846  Val accuracy: 85.3333%  Loss_test: 0.011910 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00144
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 37  Train accuracy: 98.6446%  Loss_train: 0.001776  Val accuracy: 85.3333%  Loss_test: 0.009482 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00071
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 38  Train accuracy: 99.3976%  Loss_train: 0.001335  Val accuracy: 88.0000%  Loss_test: 0.009863 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00359
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 39  Train accuracy: 98.9458%  Loss_train: 0.001696  Val accuracy: 80.0000%  Loss_test: 0.012400 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00223
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 40  Train accuracy: 98.7952%  Loss_train: 0.001519  Val accuracy: 80.0000%  Loss_test: 0.010966 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00068
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 41  Train accuracy: 99.3976%  Loss_train: 0.001225  Val accuracy: 90.6667%  Loss_test: 0.008763 (improved)
#               precision    recall  f1-score   support
#
#          0.0     0.8919    0.9167    0.9041        36
#          1.0     0.9211    0.8974    0.9091        39
#
#     accuracy                         0.9067        75
#    macro avg     0.9065    0.9071    0.9066        75
# weighted avg     0.9071    0.9067    0.9067        75
#
# Iteration: 83/83 (100.0%)  Loss: 0.00165
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 42  Train accuracy: 99.6988%  Loss_train: 0.001124  Val accuracy: 90.6667%  Loss_test: 0.009146 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00050
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 43  Train accuracy: 99.5482%  Loss_train: 0.001395  Val accuracy: 89.3333%  Loss_test: 0.008277 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00040
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 44  Train accuracy: 99.8494%  Loss_train: 0.000896  Val accuracy: 86.6667%  Loss_test: 0.012239 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00022
# Elapsed: 2.4
# Estimated remaining time: 0.2 hours
# Epoch: 45  Train accuracy: 99.6988%  Loss_train: 0.000705  Val accuracy: 86.6667%  Loss_test: 0.009183 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00127
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 46  Train accuracy: 99.2470%  Loss_train: 0.001328  Val accuracy: 78.6667%  Loss_test: 0.015996 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00034
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 47  Train accuracy: 99.6988%  Loss_train: 0.001144  Val accuracy: 85.3333%  Loss_test: 0.012455 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00054
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 48  Train accuracy: 97.8916%  Loss_train: 0.002329  Val accuracy: 89.3333%  Loss_test: 0.012126 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00281
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 49  Train accuracy: 99.6988%  Loss_train: 0.001222  Val accuracy: 86.6667%  Loss_test: 0.011220 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00040
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 50  Train accuracy: 99.6988%  Loss_train: 0.000942  Val accuracy: 90.6667%  Loss_test: 0.011751 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00018
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 51  Train accuracy: 100.0000%  Loss_train: 0.000582  Val accuracy: 89.3333%  Loss_test: 0.007964 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00200
# Elapsed: 2.4
# Estimated remaining time: 0.2 hours
# Epoch: 52  Train accuracy: 100.0000%  Loss_train: 0.000642  Val accuracy: 92.0000%  Loss_test: 0.008551 (improved)
#               precision    recall  f1-score   support
#
#          0.0     1.0000    0.8333    0.9091        36
#          1.0     0.8667    1.0000    0.9286        39
#
#     accuracy                         0.9200        75
#    macro avg     0.9333    0.9167    0.9188        75
# weighted avg     0.9307    0.9200    0.9192        75
#
# Iteration: 83/83 (100.0%)  Loss: 0.00016
# Elapsed: 2.4
# Estimated remaining time: 0.2 hours
# Epoch: 53  Train accuracy: 100.0000%  Loss_train: 0.000507  Val accuracy: 86.6667%  Loss_test: 0.008052 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00035
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 54  Train accuracy: 100.0000%  Loss_train: 0.000389  Val accuracy: 90.6667%  Loss_test: 0.007725 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00013
# Elapsed: 2.4
# Estimated remaining time: 0.2 hours
# Epoch: 55  Train accuracy: 100.0000%  Loss_train: 0.000344  Val accuracy: 90.6667%  Loss_test: 0.008107 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00108
# Elapsed: 2.5
# Estimated remaining time: 0.2 hours
# Epoch: 56  Train accuracy: 100.0000%  Loss_train: 0.000349  Val accuracy: 90.6667%  Loss_test: 0.010097 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00016
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 57  Train accuracy: 100.0000%  Loss_train: 0.000517  Val accuracy: 89.3333%  Loss_test: 0.009282 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00012
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 58  Train accuracy: 100.0000%  Loss_train: 0.000348  Val accuracy: 94.6667%  Loss_test: 0.009096 (improved)
#               precision    recall  f1-score   support
#
#          0.0     1.0000    0.8889    0.9412        36
#          1.0     0.9070    1.0000    0.9512        39
#
#     accuracy                         0.9467        75
#    macro avg     0.9535    0.9444    0.9462        75
# weighted avg     0.9516    0.9467    0.9464        75
#
# Iteration: 83/83 (100.0%)  Loss: 0.00014
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 59  Train accuracy: 100.0000%  Loss_train: 0.000269  Val accuracy: 92.0000%  Loss_test: 0.007450 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00025
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 60  Train accuracy: 100.0000%  Loss_train: 0.000323  Val accuracy: 90.6667%  Loss_test: 0.007856 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00015
# Elapsed: 2.4
# Estimated remaining time: 0.2 hours
# Epoch: 61  Train accuracy: 100.0000%  Loss_train: 0.000295  Val accuracy: 92.0000%  Loss_test: 0.007417 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00022
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 62  Train accuracy: 100.0000%  Loss_train: 0.000258  Val accuracy: 93.3333%  Loss_test: 0.007576 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00034
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 63  Train accuracy: 100.0000%  Loss_train: 0.000223  Val accuracy: 92.0000%  Loss_test: 0.007797 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00844
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 64  Train accuracy: 98.6446%  Loss_train: 0.001713  Val accuracy: 77.3333%  Loss_test: 0.013306 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00371
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 65  Train accuracy: 97.7410%  Loss_train: 0.003840  Val accuracy: 86.6667%  Loss_test: 0.009439 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.01059
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 66  Train accuracy: 99.5482%  Loss_train: 0.001800  Val accuracy: 88.0000%  Loss_test: 0.014990 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00058
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 67  Train accuracy: 77.5602%  Loss_train: 0.005687  Val accuracy: 88.0000%  Loss_test: 0.012030 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00024
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 68  Train accuracy: 97.8916%  Loss_train: 0.002682  Val accuracy: 86.6667%  Loss_test: 0.009895 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00152
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 69  Train accuracy: 99.5482%  Loss_train: 0.001582  Val accuracy: 88.0000%  Loss_test: 0.013179 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00144
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 70  Train accuracy: 98.3434%  Loss_train: 0.002523  Val accuracy: 84.0000%  Loss_test: 0.015688 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00026
# Elapsed: 2.3
# Estimated remaining time: 0.2 hours
# Epoch: 71  Train accuracy: 99.8494%  Loss_train: 0.000734  Val accuracy: 89.3333%  Loss_test: 0.008752 (improved)
# Iteration: 83/83 (100.0%)  Loss: 0.00043
# Elapsed: 2.2
# Estimated remaining time: 0.2 hours
# Epoch: 72  Train accuracy: 99.5482%  Loss_train: 0.001616  Val accuracy: 89.3333%  Loss_test: 0.008525 (improved)
# Iteration: 46/83 (55.4%)  Loss: 0.00382

# %%
# print(confusion_matrix(Test_label, y_pred_all[:,epoch]))
# print(classification_report(Test_label, y_pred_all[:,epoch]))
y_pred_all[: , 2]
